# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
#from imblearn.over_sampling import SMOTE

df  = pd.read_csv('C:/Users/pc/Downloads/cuisines (2).csv')
df.head()
df.cuisine.value_counts().plot.barh()
def create_ingredient_df(df):
    ingredient_df = df.T.drop(['cuisine','Unnamed: 0']).sum(axis=1).to_frame('value')
    ingredient_df = ingredient_df[(ingredient_df.T != 0).any()]
    ingredient_df = ingredient_df.sort_values(by='value', ascending=False,
    inplace=False)
    return ingredient_df
thai_ingredient_df = create_ingredient_df('thai_df')
thai_ingredient_df.head(10).plot.barh()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 16
#      13     ingredient_df = ingredient_df.sort_values(by='value', ascending=False,
#      14     inplace=False)
#      15     return ingredient_df
# ---> 16 thai_ingredient_df = create_ingredient_df('thai_df')
#      17 thai_ingredient_df.head(10).plot.barh()
#
# Cell In[2], line 11, in create_ingredient_df(df)
#      10 def create_ingredient_df(df):
# ---> 11     ingredient_df = df.T.drop(['cuisine','Unnamed: 0']).sum(axis=1).to_frame('value')
#      12     ingredient_df = ingredient_df[(ingredient_df.T != 0).any()]
#      13     ingredient_df = ingredient_df.sort_values(by='value', ascending=False,
#      14     inplace=False)
#
# AttributeError: 'str' object has no attribute 'T'
