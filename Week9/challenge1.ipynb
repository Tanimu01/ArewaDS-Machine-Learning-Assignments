# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import os
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/pc/Downloads/energy (1).csv')
df.info()
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.set_index('timestamp', inplace=True)

df['2013-07-01':'2014-07-07'].plot(y='load', subplots=True, figsize=(15, 8), fontsize=12)
plt.xlabel('timestamp', fontsize=12)
plt.ylabel('load', fontsize=12)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26304 entries, 0 to 26303
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  26304 non-null  object
#  1   load       26304 non-null  float64
#  2   temp       26304 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 616.6+ KB

# %% [markdown]
# Industries and Areas of Inquiry that Benefit from Time Series Forecasting:
#
# Finance: Time series forecasting is extensively used in financial markets for predicting stock prices, currency exchange rates, and financial indices.
# Retail: Retailers use time series forecasting to predict sales demand, optimize inventory management, and plan promotions and pricing strategies.
# Supply Chain Management: Time series forecasting helps in forecasting demand, managing inventory levels, and optimizing supply chain operations.
# Energy: Time series forecasting is crucial for predicting electricity consumption, optimizing energy production, and managing renewable energy resources.
# Healthcare: Forecasting patient admissions, disease outbreaks, and medical resource demand helps healthcare organizations plan and allocate resources effectively.
# Transportation: Time series forecasting assists in predicting travel demand, optimizing transportation routes, and managing logistics operations.
# Weather Forecasting: Meteorological agencies utilize time series forecasting to predict weather patterns, including temperature, rainfall, and severe weather events.
# Econometrics: Time series forecasting is widely used in economic research and analysis, such as predicting GDP growth, inflation rates, and unemployment rates.
# Ecology and Environmental Sciences: Time series forecasting helps in predicting ecological patterns, species population dynamics, and climate change impacts.
# Marketing and Advertising: Forecasting customer behavior, campaign response rates, and market trends assists in planning marketing strategies and budget allocation.
# Application of Time Series Forecasting in the Arts:
# Time series forecasting techniques can be applied in the arts to analyze and predict various aspects, such as:
#
# Box Office Performance: Forecasting ticket sales for movies, theater performances, and concerts.
# Art Sales: Predicting the demand and price trends for artworks and collectibles.
# Cultural Event Attendance: Forecasting the number of attendees for festivals, exhibitions, and cultural events.
# Music Streaming and Downloads: Predicting the popularity and consumption patterns of music tracks and albums.
# Trend Analysis: Forecasting fashion trends and design preferences in the fashion industry.
# Overall, time series forecasting has wide-ranging applications across industries and areas of inquiry, providing valuable insights for planning, decision-making, and resource optimization.
