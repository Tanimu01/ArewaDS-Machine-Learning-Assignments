# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from sklearn.datasets import load_iris

# Generate some random data
data = np.random.normal(0, 1, 1000)

# Plot the histogram
plt.hist(data, bins=30, density=True)
data
# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Random Data')


# Load the image
img = cv2.imread('tanimu.jpg', cv2.IMREAD_GRAYSCALE)

# Calculate the histogram
hist = cv2.calcHist([img], [0], None, [256], [0, 256])

# Plot the histogram
plt.plot(hist)

# Add labels and title
plt.xlabel('Pixel Value')
plt.ylabel('Frequency')
plt.title('Histogram of Image')

# Show the plot
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_bunch.py:35, in Bunch.__getattr__(self, key)
#      34 try:
# ---> 35     return self[key]
#      36 except KeyError:
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 35
#      33 plt.show()
#      34 data1 = load_iris()
# ---> 35 data1.head()
#
# File c:\Users\pc\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_bunch.py:37, in Bunch.__getattr__(self, key)
#      35     return self[key]
#      36 except KeyError:
# ---> 37     raise AttributeError(key)
#
# AttributeError: head
